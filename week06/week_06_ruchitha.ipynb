# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Dataset: Global Energy Mix by Country and Source
df = pd.read_csv('/content/global_energy_mix.csv')

# Source type mapping — reuse from lecture
source_category = {
    'Coal': 'Fossil', 'Oil': 'Fossil', 'Natural Gas': 'Fossil',
    'Nuclear': 'Low-carbon', 'Hydro': 'Low-carbon',
    'Wind': 'Renewable', 'Solar': 'Renewable', 'Other Renewables': 'Renewable'
}
df['Source_Type'] = df['Source'].map(source_category)

print(f"Loaded: {len(df)} rows")
print(df.head(10))
# Out:
# Loaded: 103 rows
#          Country         Region            Source  Share_pct     TWh  \
# 0  United States  North America              Coal         10  1015.0
# 1  United States  North America               Oil         35  3220.0
# 2  United States  North America       Natural Gas         34  3083.0
# 3  United States  North America           Nuclear          9   798.0
# 4  United States  North America             Hydro          3   339.0
# 5  United States  North America              Wind          4   413.0
# 6  United States  North America             Solar          3   325.0
# 7  United States  North America  Other Renewables          2   229.0
# 8          China           Asia              Coal         60  7168.0
# 9          China           Asia               Oil         18  1620.0
#
#   Source_Type
# 0      Fossil
# 1      Fossil
# 2      Fossil
# 3  Low-carbon
# 4  Low-carbon
# 5   Renewable
# 6   Renewable
# 7   Renewable
# 8      Fossil
# 9      Fossil

# %% [markdown]
# ## Task 1 — Treemap: fossil fuel dependency by **country**

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('/content/global_energy_mix.csv')

# Fossil fuel sources
fossil_sources = ['Coal', 'Oil', 'Natural Gas']

fossil = df[df['Source'].isin(fossil_sources)]

# Treemap
fig = px.treemap(
    fossil,
    path=['Region', 'Country', 'Source'],
    values='TWh',
    color='Source',
    title='Fossil fuel dependency varies across countries and regions'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="487d037d-7a8e-47b4-a903-216fd6946502" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("487d037d-7a8e-47b4-a903-216fd6946502")) {                    Plotly.newPlot(                        "487d037d-7a8e-47b4-a903-216fd6946502",                        [{"branchvalues":"total","customdata":[["Coal"],["Oil"],["Oil"],["Oil"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Coal"],["Natural Gas"],["Coal"],["Coal"],["Coal"],["Natural Gas"],["Oil"],["Coal"],["Oil"],["Oil"],["Oil"],["Oil"],["Coal"],["Natural Gas"],["Oil"],["Natural Gas"],["Coal"],["Coal"],["Natural Gas"],["Natural Gas"],["Oil"],["Coal"],["Oil"],["Natural Gas"],["Oil"],["Oil"],["Natural Gas"],["Natural Gas"],["Oil"],["Oil"],["Coal"],["Natural Gas"],["Natural Gas"],["Coal"],["Coal"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eTWh=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eSource=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Oceania\u002fAustralia\u002fCoal","Asia\u002fSouth Korea\u002fOil","Europe\u002fNorway\u002fOil","Asia\u002fIndia\u002fOil","North America\u002fUnited States\u002fNatural Gas","Africa\u002fSouth Africa\u002fNatural Gas","Europe\u002fGermany\u002fNatural Gas","North America\u002fCanada\u002fNatural Gas","North America\u002fUnited States\u002fCoal","Latin America\u002fMexico\u002fNatural Gas","Asia\u002fChina\u002fCoal","Asia\u002fIndia\u002fCoal","Africa\u002fSouth Africa\u002fCoal","Europe\u002fUnited Kingdom\u002fNatural Gas","Africa\u002fSouth Africa\u002fOil","North America\u002fCanada\u002fCoal","Latin America\u002fMexico\u002fOil","Europe\u002fGermany\u002fOil","Asia\u002fChina\u002fOil","Latin America\u002fBrazil\u002fOil","Europe\u002fGermany\u002fCoal","Middle East\u002fSaudi Arabia\u002fNatural Gas","North America\u002fUnited States\u002fOil","Asia\u002fJapan\u002fNatural Gas","Europe\u002fUnited Kingdom\u002fCoal","Latin America\u002fMexico\u002fCoal","Europe\u002fFrance\u002fNatural Gas","Latin America\u002fBrazil\u002fNatural Gas","Europe\u002fUnited Kingdom\u002fOil","Latin America\u002fBrazil\u002fCoal","Middle East\u002fSaudi Arabia\u002fOil","Oceania\u002fAustralia\u002fNatural Gas","Asia\u002fJapan\u002fOil","Europe\u002fFrance\u002fOil","Europe\u002fNorway\u002fNatural Gas","Asia\u002fChina\u002fNatural Gas","North America\u002fCanada\u002fOil","Oceania\u002fAustralia\u002fOil","Europe\u002fFrance\u002fCoal","Asia\u002fIndia\u002fNatural Gas","Asia\u002fSouth Korea\u002fNatural Gas","Asia\u002fJapan\u002fCoal","Asia\u002fSouth Korea\u002fCoal","Oceania\u002fAustralia","Latin America\u002fBrazil","North America\u002fCanada","Asia\u002fChina","Europe\u002fFrance","Europe\u002fGermany","Asia\u002fIndia","Asia\u002fJapan","Latin America\u002fMexico","Europe\u002fNorway","Middle East\u002fSaudi Arabia","Africa\u002fSouth Africa","Asia\u002fSouth Korea","Europe\u002fUnited Kingdom","North America\u002fUnited States","Africa","Asia","Europe","Latin America","Middle East","North America","Oceania"],"labels":["Coal","Oil","Oil","Oil","Natural Gas","Natural Gas","Natural Gas","Natural Gas","Coal","Natural Gas","Coal","Coal","Coal","Natural Gas","Oil","Coal","Oil","Oil","Oil","Oil","Coal","Natural Gas","Oil","Natural Gas","Coal","Coal","Natural Gas","Natural Gas","Oil","Coal","Oil","Natural Gas","Oil","Oil","Natural Gas","Natural Gas","Oil","Oil","Coal","Natural Gas","Natural Gas","Coal","Coal","Australia","Brazil","Canada","China","France","Germany","India ...

# %% [markdown]
# Task 2 — Sunburst: tipping behaviour by day and meal time

# %%
tips = px.data.tips()

# Grouping
df_sun = (
    tips.groupby(['day', 'time', 'sex'])['total_bill']
    .sum()
    .reset_index()
)

# Sunburst chart
fig = px.sunburst(
    df_sun,
    path=['day', 'time', 'sex'],
    values='total_bill',
    color='sex',
    title='Dinner periods generate higher total bills across the week'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3c37b439-3421-41e8-b07a-a2785ee92bd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c37b439-3421-41e8-b07a-a2785ee92bd9")) {                    Plotly.newPlot(                        "3c37b439-3421-41e8-b07a-a2785ee92bd9",                        [{"branchvalues":"total","customdata":[["Female"],["Female"],["Female"],["Male"],["Male"],["Male"],["Female"],["Female"],["Female"],["Male"],["Male"],["(?)"],["(?)"],["(?)"],["Female"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003etotal_bill=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003esex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Fri\u002fDinner\u002fFemale","Sun\u002fDinner\u002fFemale","Fri\u002fLunch\u002fFemale","Fri\u002fDinner\u002fMale","Sun\u002fDinner\u002fMale","Fri\u002fLunch\u002fMale","Sat\u002fDinner\u002fFemale","Thur\u002fDinner\u002fFemale","Thur\u002fLunch\u002fFemale","Sat\u002fDinner\u002fMale","Thur\u002fLunch\u002fMale","Fri\u002fDinner","Sat\u002fDinner","Sun\u002fDinner","Thur\u002fDinner","Fri\u002fLunch","Thur\u002fLunch","Fri","Sat","Sun","Thur"],"labels":["Female","Female","Female","Male","Male","Male","Female","Female","Female","Male","Male","Dinner","Dinner","Dinner","Dinner","Lunch","Lunch","Fri","Sat","Sun","Thur"],"marker":{"colors":["#636efa","#636efa","#636efa","#EF553B","#EF553B","#EF553B","#636efa","#636efa","#636efa","#EF553B","#EF553B","#00cc96","#00cc96","#00cc96","#636efa","#00cc96","#00cc96","#00cc96","#00cc96","#00cc96","#00cc96"]},"name":"","parents":["Fri\u002fDinner","Sun\u002fDinner","Fri\u002fLunch","Fri\u002fDinner","Sun\u002fDinner","Fri\u002fLunch","Sat\u002fDinner","Thur\u002fDinner","Thur\u002fLunch","Sat\u002fDinner","Thur\u002fLunch","Fri","Sat","Sun","Thur","Fri","Thur","","","",""],"values":[71.55,357.7,55.760000000000005,164.41,1269.46,34.16,551.05,18.78,516.11,1227.35,561.4399999999999,235.95999999999998,1778.3999999999999,1627.16,18.78,89.92,1077.55,325.88,1778.3999999999999,1627.16,1096.33],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %% [markdown]
# # Task 3 — Treemap vs Bar Chart

# %%
# Renewable sources
renewables = ['Hydro', 'Wind', 'Solar']

low_carbon = (
    df[df['Source'].isin(renewables)]
    .groupby('Country')['TWh']
    .sum()
    .reset_index()
    .sort_values(by='TWh', ascending=False)
)

# Treemap
fig1 = px.treemap(
    low_carbon,
    path=['Country'],
    values='TWh',
    title='Treemap of renewable energy production by country'
)

fig1.show()

# Bar chart
fig2 = px.bar(
    low_carbon.head(15),
    x='TWh',
    y='Country',
    orientation='h',
    title='Bar charts make country comparison easier for renewable energy'
)

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd1b37aa-b73d-4975-90f1-55ed956c3a73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd1b37aa-b73d-4975-90f1-55ed956c3a73")) {                    Plotly.newPlot(                        "bd1b37aa-b73d-4975-90f1-55ed956c3a73",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eTWh=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Australia","Brazil","Canada","China","France","Germany","India","Japan","Mexico","Norway","Saudi Arabia","South Africa","South Korea","United Kingdom","United States"],"labels":["Australia","Brazil","Canada","China","France","Germany","India","Japan","Mexico","Norway","Saudi Arabia","South Africa","South Korea","United Kingdom","United States"],"name":"","parents":["","","","","","","","","","","","","","",""],"values":[2025.0,5482.0,5184.0,942.0,1431.0,3615.0,1823.0,900.0,1184.0,6662.0,96.0,775.0,492.0,2311.0,1077.0],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewid ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cf840c7d-40c4-4ff2-a693-66d51a20c755" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf840c7d-40c4-4ff2-a693-66d51a20c755")) {                    Plotly.newPlot(                        "cf840c7d-40c4-4ff2-a693-66d51a20c755",                        [{"alignmentgroup":"True","hovertemplate":"TWh=%{x}\u003cbr\u003eCountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[6662.0,5482.0,5184.0,3615.0,2311.0,2025.0,1823.0,1431.0,1184.0,1077.0,942.0,900.0,775.0,492.0,96.0],"xaxis":"x","y":["Norway","Brazil","Canada","Germany","United Kingdom","Australia","India","France","Mexico","United States","China","Japan","South Africa","South Korea","Saudi Arabia"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color": ...
